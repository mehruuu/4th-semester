# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
train =pd.read_csv(r"c:\Users\CWW\Downloads\train (1).csv")
test =pd.read_csv(r"c:\Users\CWW\Downloads\test (1).csv")

# %%
train
# Out:
#      PassengerId HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# 0        0001_01     Europa     False     B/0/P    TRAPPIST-1e  39.0  False
# 1        0002_01      Earth     False     F/0/S    TRAPPIST-1e  24.0  False
# 2        0003_01     Europa     False     A/0/S    TRAPPIST-1e  58.0   True
# 3        0003_02     Europa     False     A/0/S    TRAPPIST-1e  33.0  False
# 4        0004_01      Earth     False     F/1/S    TRAPPIST-1e  16.0  False
# ...          ...        ...       ...       ...            ...   ...    ...
# 8688     9276_01     Europa     False    A/98/P    55 Cancri e  41.0   True
# 8689     9278_01      Earth      True  G/1499/S  PSO J318.5-22  18.0  False
# 8690     9279_01      Earth     False  G/1500/S    TRAPPIST-1e  26.0  False
# 8691     9280_01     Europa     False   E/608/S    55 Cancri e  32.0  False
# 8692     9280_02     Europa     False   E/608/S    TRAPPIST-1e  44.0  False
#
# ...

# %%
test
# Out:
#      PassengerId HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# 0        0013_01      Earth      True     G/3/S    TRAPPIST-1e  27.0  False
# 1        0018_01      Earth     False     F/4/S    TRAPPIST-1e  19.0  False
# 2        0019_01     Europa      True     C/0/S    55 Cancri e  31.0  False
# 3        0021_01     Europa     False     C/1/S    TRAPPIST-1e  38.0  False
# 4        0023_01      Earth     False     F/5/S    TRAPPIST-1e  20.0  False
# ...          ...        ...       ...       ...            ...   ...    ...
# 4272     9266_02      Earth      True  G/1496/S    TRAPPIST-1e  34.0  False
# 4273     9269_01      Earth     False       NaN    TRAPPIST-1e  42.0  False
# 4274     9271_01       Mars      True   D/296/P    55 Cancri e   NaN  False
# 4275     9273_01     Europa     False   D/297/P            NaN   NaN  False
# 4276     9277_01      Earth      True  G/1498/S  PSO J318.5-22  43.0  False
#
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8693 entries, 0 to 8692
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PassengerId   8693 non-null   object
#  1   HomePlanet    8492 non-null   object
#  2   CryoSleep     8476 non-null   object
#  3   Cabin         8494 non-null   object
#  4   Destination   8511 non-null   object
#  5   Age           8514 non-null   float64
#  6   VIP           8490 non-null   object
#  7   RoomService   8512 non-null   float64
#  8   FoodCourt     8510 non-null   float64
#  9   ShoppingMall  8485 non-null   float64
#  10  Spa           8510 non-null   float64
#  11  VRDeck        8505 non-null   float64
#  12  Name          8493 non-null   object
#  13  Transported   8693 non-null   bool
# dtypes: bool(1), float64(6), object(7)
# memory usage: 891.5+ KB

# %%
train.dropna()
# Out:
#      PassengerId HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# 0        0001_01     Europa     False     B/0/P    TRAPPIST-1e  39.0  False
# 1        0002_01      Earth     False     F/0/S    TRAPPIST-1e  24.0  False
# 2        0003_01     Europa     False     A/0/S    TRAPPIST-1e  58.0   True
# 3        0003_02     Europa     False     A/0/S    TRAPPIST-1e  33.0  False
# 4        0004_01      Earth     False     F/1/S    TRAPPIST-1e  16.0  False
# ...          ...        ...       ...       ...            ...   ...    ...
# 8688     9276_01     Europa     False    A/98/P    55 Cancri e  41.0   True
# 8689     9278_01      Earth      True  G/1499/S  PSO J318.5-22  18.0  False
# 8690     9279_01      Earth     False  G/1500/S    TRAPPIST-1e  26.0  False
# 8691     9280_01     Europa     False   E/608/S    55 Cancri e  32.0  False
# 8692     9280_02     Europa     False   E/608/S    TRAPPIST-1e  44.0  False
#
# ...

# %%
for cols in train.columns:
    print(cols)
# Out:
# PassengerId
# HomePlanet
# CryoSleep
# Cabin
# Destination
# Age
# VIP
# RoomService
# FoodCourt
# ShoppingMall
# Spa
# VRDeck
# Name
# Transported

# %%
train.describe()
# Out:
#                Age   RoomService     FoodCourt  ShoppingMall           Spa  \
# count  8514.000000   8512.000000   8510.000000   8485.000000   8510.000000
# mean     28.827930    224.687617    458.077203    173.729169    311.138778
# std      14.489021    666.717663   1611.489240    604.696458   1136.705535
# min       0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      19.000000      0.000000      0.000000      0.000000      0.000000
# 50%      27.000000      0.000000      0.000000      0.000000      0.000000
# 75%      38.000000     47.000000     76.000000     27.000000     59.000000
# max      79.000000  14327.000000  29813.000000  23492.000000  22408.000000
#
#              VRDeck
# count   8505.000000
# mean     304.854791
# std     1145.717189
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       46.000000
# max    24133.000000

# %%
train.isnull().sum()
# Out:
# PassengerId       0
# HomePlanet      201
# CryoSleep       217
# Cabin           199
# Destination     182
# Age             179
# VIP             203
# RoomService     181
# FoodCourt       183
# ShoppingMall    208
# Spa             183
# VRDeck          188
# Name            200
# Transported       0
# dtype: int64

# %%
print(f"Number of Rows: {train.shape[0]} \nNumber of Columns: {train.shape[1]}")
# Out:
# Number of Rows: 8693
# Number of Columns: 14

# %%
print(test.count())
# Out:
# PassengerId     4277
# HomePlanet      4190
# CryoSleep       4184
# Cabin           4177
# Destination     4185
# Age             4186
# VIP             4184
# RoomService     4195
# FoodCourt       4171
# ShoppingMall    4179
# Spa             4176
# VRDeck          4197
# Name            4183
# dtype: int64

# %%
train['CryoSleep'] = train['CryoSleep'].fillna(False)
test['CryoSleep'] = test['CryoSleep'].fillna(False)

train['HomePlanet'] = train['HomePlanet'].fillna('Unknown')
test['HomePlanet'] = test['HomePlanet'].fillna('Unknown')

train['Destination'] = train['Destination'].fillna('Unknown')
test['Destination'] = test['Destination'].fillna('Unknown')

train['Age'] = train['Age'].fillna(train['Age'].median())
test['Age'] = test['Age'].fillna(test['Age'].median())

# %%
train.drop(['Name', 'Cabin'], axis=1, inplace=True)
train.drop(['RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck',"VIP"], axis=1, inplace=True)

# %%
test.drop(['Name', 'Cabin'], axis=1, inplace=True)
test.drop(['RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck',"VIP"], axis=1, inplace=True)

# %%
train
# Out:
#      PassengerId HomePlanet  CryoSleep    Destination   Age  Transported
# 0        0001_01     Europa      False    TRAPPIST-1e  39.0        False
# 1        0002_01      Earth      False    TRAPPIST-1e  24.0         True
# 2        0003_01     Europa      False    TRAPPIST-1e  58.0        False
# 3        0003_02     Europa      False    TRAPPIST-1e  33.0        False
# 4        0004_01      Earth      False    TRAPPIST-1e  16.0         True
# ...          ...        ...        ...            ...   ...          ...
# 8688     9276_01     Europa      False    55 Cancri e  41.0        False
# 8689     9278_01      Earth       True  PSO J318.5-22  18.0        False
# 8690     9279_01      Earth      False    TRAPPIST-1e  26.0         True
# 8691     9280_01     Europa      False    55 Cancri e  32.0        False
# 8692     9280_02     Europa      False    TRAPPIST-1e  44.0         True
#
# [8693 rows x 6 columns]

# %%
categorical_columns = ['HomePlanet', 'CryoSleep', 'Destination']
label_encoders = {}
for col in categorical_columns:
    le = LabelEncoder()
    train[col] = le.fit_transform(train[col])
    test[col] = le.transform(test[col])
    label_encoders[col] = le

# %%
train
# Out:
#      PassengerId  HomePlanet  CryoSleep  Destination   Age  Transported
# 0        0001_01           1          0            2  39.0        False
# 1        0002_01           0          0            2  24.0         True
# 2        0003_01           1          0            2  58.0        False
# 3        0003_02           1          0            2  33.0        False
# 4        0004_01           0          0            2  16.0         True
# ...          ...         ...        ...          ...   ...          ...
# 8688     9276_01           1          0            0  41.0        False
# 8689     9278_01           0          1            1  18.0        False
# 8690     9279_01           0          0            2  26.0         True
# 8691     9280_01           1          0            0  32.0        False
# 8692     9280_02           1          0            2  44.0         True
#
# [8693 rows x 6 columns]

# %%
test
# Out:
#      PassengerId  HomePlanet  CryoSleep  Destination   Age
# 0        0013_01           0          1            2  27.0
# 1        0018_01           0          0            2  19.0
# 2        0019_01           1          1            0  31.0
# 3        0021_01           1          0            2  38.0
# 4        0023_01           0          0            2  20.0
# ...          ...         ...        ...          ...   ...
# 4272     9266_02           0          1            2  34.0
# 4273     9269_01           0          0            2  42.0
# 4274     9271_01           2          1            0  26.0
# 4275     9273_01           1          0            3  26.0
# 4276     9277_01           0          1            1  43.0
#
# [4277 rows x 5 columns]

# %%
X_train = train.drop('Transported', axis=1)
y_train = train['Transported'].astype(int)  
X_test = test

# %%
X_train
# Out:
#      PassengerId  HomePlanet  CryoSleep  Destination   Age
# 0        0001_01           1          0            2  39.0
# 1        0002_01           0          0            2  24.0
# 2        0003_01           1          0            2  58.0
# 3        0003_02           1          0            2  33.0
# 4        0004_01           0          0            2  16.0
# ...          ...         ...        ...          ...   ...
# 8688     9276_01           1          0            0  41.0
# 8689     9278_01           0          1            1  18.0
# 8690     9279_01           0          0            2  26.0
# 8691     9280_01           1          0            0  32.0
# 8692     9280_02           1          0            2  44.0
#
# [8693 rows x 5 columns]

# %%
X_test
# Out:
#      PassengerId  HomePlanet  CryoSleep  Destination   Age
# 0        0013_01           0          1            2  27.0
# 1        0018_01           0          0            2  19.0
# 2        0019_01           1          1            0  31.0
# 3        0021_01           1          0            2  38.0
# 4        0023_01           0          0            2  20.0
# ...          ...         ...        ...          ...   ...
# 4272     9266_02           0          1            2  34.0
# 4273     9269_01           0          0            2  42.0
# 4274     9271_01           2          1            0  26.0
# 4275     9273_01           1          0            3  26.0
# 4276     9277_01           0          1            1  43.0
#
# [4277 rows x 5 columns]

# %%
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)


y_pred = model.predict(X_test)

# %%
submission = pd.DataFrame({'PassengerId': X_test['PassengerId'], 'Transported': y_pred})
submission['Transported'] = submission['Transported'].astype(bool)  
submission.to_csv('submission.csv', index=False)

# %%
submission
# Out:
#      PassengerId  Transported
# 0        0013_01         True
# 1        0018_01        False
# 2        0019_01         True
# 3        0021_01        False
# 4        0023_01        False
# ...          ...          ...
# 4272     9266_02        False
# 4273     9269_01         True
# 4274     9271_01         True
# 4275     9273_01         True
# 4276     9277_01        False
#
# [4277 rows x 2 columns]
